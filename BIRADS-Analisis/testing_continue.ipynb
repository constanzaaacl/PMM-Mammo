# %% [markdown]
# ## Pycaret ##

# %%
pip install pycaret
# Out:
# ...
#
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/21.8 MB ? eta -:--:--
#    --- ------------------------------------ 1.8/21.8 MB 10.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 6.3/21.8 MB 16.8 MB/s eta 0:00:01
#    ------------------------- -------------- 13.6/21.8 MB 22.5 MB/s eta 0:00:01
#    ------------------------- -------------- 14.2/21.8 MB 17.8 MB/s eta 0:00:01
#    -------------------------------------- - 21.2/21.8 MB 21.0 MB/s eta 0:00:01
#    ---------------------------------------  21.8/21.8 MB 20.8 MB/s eta 0:00:01
#    ---------------------------------------- 21.8/21.8 MB 17.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/65.9 MB ? eta -:--:--
#    ---- ----------------------------------- 7.6/65.9 MB 36.2 MB/s eta 0:00:02
#    ------ --------------------------------- 10.2/65.9 MB 23.6 MB/s eta 0:00:03
# ...
