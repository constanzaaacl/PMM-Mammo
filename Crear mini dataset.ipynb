 'c7d4256d3018a2f5b538651bb9c352a1',
 '53190280d30e3cf56029dbd9742c95ba',
 '40a4a4b5d0359ffe197053b0dce4b1ad',
 'df6c67e042bbc9616e308f48b0a24093',
 '0676f4386325058f95263c823b0ee347',
 '2a2f16faed22c68f36807fe30f741637',
 '68e91b38fe4b19befc3d33bfacac5e1e',
 '716ba66b9cf0cb182ea0d85309019e48',
 '12b0db966e11c6476cf9134f254fb1b1',
 '5d97254382a3079830523a3b1bb427bf',
 'b622b289622087b930fbfea9baaf3ba8',
 'e918d30cfad5b412496285cc3f49d582',
 'c20146cbab7a5d4b5f56a3dff23cbcae',
 '14716db54e664ab6daa9f4d78b057680',
 '9e1fe86fa97ebabcf4839be2a18316c7',
 '7ce8bcd7af37dda66103b5b7ba6762e3',
 'a9806aea2c2a812e3495c594b70a2622',
 'd4d0d944cb75e47258c454995f774dc5',
 '2c4cc5495e3fa8f1b4eeab6798714449',
 '1ebe2a31f31a19a1e872e63a6772b88b',
 'a22854b8bc1e6379b5da1460772e8f18',
 '12aca50c0fd2b6309e42d9244559cade',
 'fede4ad436908ef7250370ffb6ff9b41',
 'b8e9429869be9c69810619f71778abad',
 '76a3bd50a074f5d99ef691acf7ffc9a6',
 'da17728ab905a565051f16986aafda50',
 '4b31fd58a3f25c683ffd9eb96c43245a',
 '82db56c444f262e6a0e43908b26ebf54',
 '29bfec1e3b5a67751abc3dbf46df3e62',
 'bb307884bfe5da3db54b94b736f10023',
 'd2df932837bbafb9d7bd1bca86df397a',
'a384c133416b47e3a4eb4df1f519748a',
'd7169c8f349e5c37fc0cf2ce78cdd4cb',
'33ba87f3cb50eecd488780ded80c964b',
'9535a28c4ced8513bfa77dc10c06bed9']

# %%
zip_path = 'vindr-mammo-a-large-scale-benchmark-dataset-for-computer-aided-detection-and-diagnosis-in-full-field-digital-mammography-1.0.0 (1).zip'
destination_root = 'VinMini'

# %%
# Abrir el archivo ZIP
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    # Obtener la lista de todos los archivos en el ZIP
    all_files = zip_ref.namelist()
    
    for series_id in selected_series_ids:
        # Filtrar archivos que pertenecen a la serie actual dentro de la carpeta 'images'
        series_files = [file for file in all_files if file.startswith(f"vindr-mammo-a-large-scale-benchmark-dataset-for-computer-aided-detection-and-diagnosis-in-full-field-digital-mammography-1.0.0/images/{series_id}/") and file.endswith('.dicom')]
        
        if not series_files:
            print(f"No se encontraron archivos DICOM para el series_id: {series_id}.")
            continue
        
        # Crear el directorio de destino para la serie
        destination_dir = os.path.join(destination_root, series_id)
        os.makedirs(destination_dir, exist_ok=True)
        
        for file_name in series_files:
            # Extraer cada archivo y copiar al directorio de destino
            with zip_ref.open(file_name) as source_file:
                # Generar la ruta del archivo destino dentro del directorio creado
                destination_file_path = os.path.join(destination_dir, os.path.basename(file_name))
                with open(destination_file_path, 'wb') as dest_file:
                    shutil.copyfileobj(source_file, dest_file)

print("Las imágenes han sido copiadas exitosamente.")
# Out:
# Las imágenes han sido copiadas exitosamente.

# %%
import os
import shutil
import Zipfile

# Ruta de origen y destino
source_root = '/Volumes/m2/Memoria/Datasets/vindr/images'
destination_root = 'VinMini'

zip_path = 'vindr-mammo-a-large-scale-benchmark-dataset-for-computer-aided-detection-and-diagnosis-in-full-field-digital-mammography-1.0.0 (1).zip'


# Lista completa de series_id 
selected_series_ids = ['b2e9c581abecd57e52d74512f6fa957d',
 'df6c67e042bbc9616e308f48b0a24093',
 '0676f4386325058f95263c823b0ee347',
 '2a2f16faed22c68f36807fe30f741637',
 '68e91b38fe4b19befc3d33bfacac5e1e',
 '716ba66b9cf0cb182ea0d85309019e48',
 '12b0db966e11c6476cf9134f254fb1b1',
 '5d97254382a3079830523a3b1bb427bf',
 'b622b289622087b930fbfea9baaf3ba8',
 'e918d30cfad5b412496285cc3f49d582',
 'c20146cbab7a5d4b5f56a3dff23cbcae',
 '14716db54e664ab6daa9f4d78b057680',
 '9e1fe86fa97ebabcf4839be2a18316c7',
 '7ce8bcd7af37dda66103b5b7ba6762e3',
 'a9806aea2c2a812e3495c594b70a2622',
 'd4d0d944cb75e47258c454995f774dc5',
 '2c4cc5495e3fa8f1b4eeab6798714449',
 '1ebe2a31f31a19a1e872e63a6772b88b',
 'a22854b8bc1e6379b5da1460772e8f18',
 '12aca50c0fd2b6309e42d9244559cade',
 'fede4ad436908ef7250370ffb6ff9b41',
 'b8e9429869be9c69810619f71778abad',
 '76a3bd50a074f5d99ef691acf7ffc9a6',
 'da17728ab905a565051f16986aafda50',
 '4b31fd58a3f25c683ffd9eb96c43245a',
 '82db56c444f262e6a0e43908b26ebf54',
 '29bfec1e3b5a67751abc3dbf46df3e62',
 'bb307884bfe5da3db54b94b736f10023',
 'd2df932837bbafb9d7bd1bca86df397a',
'a384c133416b47e3a4eb4df1f519748a',
'd7169c8f349e5c37fc0cf2ce78cdd4cb',
'33ba87f3cb50eecd488780ded80c964b',
'9535a28c4ced8513bfa77dc10c06bed9']

# Copiar las imágenes correspondientes a cada series_id
for series_id in selected_series_ids:
    source_dir = os.path.join(source_root, series_id)
    destination_dir = os.path.join(destination_root, series_id)
    
    # Verificar si la carpeta existe
    if not os.path.exists(source_dir):
        print(f"Carpeta no encontrada: {source_dir}, saltando este series_id.")
        continue
    
    # Crear la carpeta en el destino
    os.makedirs(destination_dir, exist_ok=True)
    
    # Copiar las imágenes DICOM dentro de la subcarpeta correspondiente
    for file_name in os.listdir(source_dir):
        if file_name.endswith('.dicom'):
            shutil.copy(os.path.join(source_dir, file_name), os.path.join(destination_dir, file_name))

print("Las imágenes han sido copiadas exitosamente.")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import os
#       2 import shutil
# ----> 3 import Zipfile
#       5 # Ruta de origen y destino
#       6 source_root = '/Volumes/m2/Memoria/Datasets/vindr/images'
#
# ModuleNotFoundError: No module named 'Zipfile'

# %%
import pandas as pd

# Cargar el archivo CSV original
df_birads = pd.read_csv('breast-level_annotations.csv')

# Filtrar el DataFrame para que solo incluya las filas con los study_id seleccionados
filtered_df = df_birads[df_birads['study_id'].isin(selected_series_ids)]

# Guardar el DataFrame filtrado como un nuevo archivo CSV
output_path = 'breast_level_comprimido.csv'
filtered_df.to_csv(output_path, index=False)

print(f"Archivo guardado en {output_path}")
# Out:
# Archivo guardado en breast_level_comprimido.csv

# %%
import pandas as pd

# Cargar el archivo CSV original
df_birads = pd.read_csv('finding_annotations.csv')

# Filtrar el DataFrame para que solo incluya las filas con los study_id seleccionados
filtered_df = df_birads[df_birads['study_id'].isin(selected_series_ids)]

# Guardar el DataFrame filtrado como un nuevo archivo CSV
output_path = 'findings_comprimido.csv'
filtered_df.to_csv(output_path, index=False)

print(f"Archivo guardado en {output_path}")
# Out:
# Archivo guardado en findings_comprimido.csv
